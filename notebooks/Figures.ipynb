# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run nb_init.py
import IPython.core.display as disp
import hdfgraph
# Out:
# 2014-04-07 09:29:56,398 -leg_joint -INFO -successfully imported leg_joint

# %%
# !ls -lth /home/guillaume/Projets/Droso/Simulations/saved_graphs/
# Out:
# total 56K
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  31 12:16 0003_2014-03-31T10_15_59
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  31 10:02 num_cell_regular
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  31 03:15 0002_2014-03-31T01_14_52
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 19:37 0001_2014-03-30T17_37_05
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 15:28 0000_2014-03-30T13_28_07
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 10:23 num_cell_rdm
# drwxr-xr-x 14 guillaume guillaume 4,0K mars  30 10:22 contractility_radial_tension
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 09:50 0000_2014-03-30T07_49_23
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 09:50 0003_2014-03-30T07_49_23
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 09:50 0001_2014-03-30T07_49_23
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  30 09:50 0002_2014-03-30T07_49_23
# drwxr-xr-x  2 guillaume guillaume 4,0K mars  23 17:19 xml
# drwxr-xr-x  6 guillaume guillaume 4,0K mars  23 17:18 single_2014-03-23T10_00_49
# drwxr-xr-x  2 guillaume guillaume 4,0K mars  23 17:18 blender

# %%
graph_dir_1 = '/home/guillaume/Projets/Droso/Simulations/saved_graphs/contractility_radial_tension/'
graph_dir_2 = '/home/guillaume/Projets/Droso/Simulations/saved_graphs/num_cell_rdm/'
graph_dir_3 = '/home/guillaume/Projets/Droso/Simulations/saved_graphs/num_cell_regular/'

# %%
def get_lists(graph_dir):
    dir_list = os.listdir(graph_dir)
    dir_list.sort()
    png_dir_list = [os.path.join(graph_dir, d, 'png') for d in dir_list]
    svg_list = [os.path.join(graph_dir, d, 'svg', 'avg_rho_%s.svg' % d) for d in dir_list]
    json_list = [os.path.join(graph_dir, d, 'params_%s.json' %d) for d in dir_list]
    xml_list = [os.path.join(graph_dir, d, 'xml', 'after_apopto.xml') for d in dir_list]
    return (dir_list, png_dir_list, svg_list, json_list, xml_list)

graph_dirs = [graph_dir_1, graph_dir_2, graph_dir_3]

big_ls = [dir_list, png_dir_list, svg_list, json_list, xml_list] = [[], [], [], [], []] 

for graph_dir in graph_dirs:
    sub_ls = get_lists(graph_dir)
    [big_l.extend(sub_l) for big_l, sub_l in zip(big_ls, sub_ls)]
    
for i, json_fname in enumerate(json_list):
    #continue
    with open(json_fname) as json_file:
        kwargs = json.load(json_file)
    print('index: {} => \n'.format(i)) 
    for key, val in kwargs['post_kwargs'].items():
        print('\t {}: {}'.format(key, val))
    print('\t radial_tension : {}'.format(
          kwargs['apopto_kwargs']['radial_tension']))
    print('\t num cells : {}'.format(
          kwargs['seq_kwargs']['num_cells']))
    print('\t random : {}'.format(
          kwargs['seq_kwargs']['random']))
    print('\n')
# Out:
# index: 0 =>
#
# 	 span_ci: 2
# 	 max_ci: 1.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.0
# 	 num cells : 30
# 	 random : True
#
#
# index: 1 =>
#
# 	 span_ci: 2
# 	 max_ci: 1.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.05
# 	 num cells : 30
# 	 random : True
#
#
# index: 2 =>
#
# 	 span_ci: 2
# 	 max_ci: 1.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 30
# 	 random : True
#
#
# index: 3 =>
#
# 	 span_ci: 2
# 	 max_ci: 1.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.2
# 	 num cells : 30
# 	 random : True
#
#
# index: 4 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.0
# 	 num cells : 30
# 	 random : True
#
#
# index: 5 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.05
# 	 num cells : 30
# 	 random : True
#
#
# index: 6 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 30
# 	 random : True
#
#
# index: 7 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.2
# 	 num cells : 30
# 	 random : True
#
#
# index: 8 =>
#
# 	 span_ci: 2
# 	 max_ci: 3.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.0
# 	 num cells : 30
# 	 random : True
#
#
# index: 9 =>
#
# 	 span_ci: 2
# 	 max_ci: 3.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.05
# 	 num cells : 30
# 	 random : True
#
#
# index: 10 =>
#
# 	 span_ci: 2
# 	 max_ci: 3.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 30
# 	 random : True
#
#
# index: 11 =>
#
# 	 span_ci: 2
# 	 max_ci: 3.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.2
# 	 num cells : 30
# 	 random : True
#
#
# index: 12 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 5
# 	 random : True
#
#
# index: 13 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 10
# 	 random : True
#
#
# index: 14 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 20
# 	 random : True
#
#
# index: 15 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 30
# 	 random : True
#
#
# index: 16 =>
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 5
# 	 random : False
#
#
# index: 17 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 10
# 	 random : False
#
#
# index: 18 =>
#
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 20
# 	 random : False
#
#
# index: 19 =>
# 	 span_ci: 2
# 	 max_ci: 2.0
# 	 rate_ci: 1.4
# 	 radial_tension : 0.1
# 	 num cells : 30
# 	 random : False

# %%
xml_paths = {#'before': '../saved_graphs/xml/before_apoptosis.xml',
             #'rt_0_ct1': xml_list[0],
             'rt_1_ct2': xml_list[6],
             #'intermediate':'../saved_graphs/xml/single_cell_before_elimination.xml',
             #'single_after':'../saved_graphs/xml/single_cell_after_elimination.xml',
             '5_random': xml_list[12],
             '5_regular': xml_list[16],
             '10_random': xml_list[13],
             '10_regular': xml_list[17],
             '20_random': xml_list[14],
             '20_regular': xml_list[18],
             '30_regular': xml_list[19],
             'rt_1_ct1': xml_list[2],
             'rt_1_ct2': xml_list[6],
             'rt_1_ct3': xml_list[10],
             'rt_0_ct2': xml_list[4],
             'rt_05_ct2': xml_list[5],
             'rt_2_ct2': xml_list[7]}

# %%
epithelia = {name: lj.Epithelium(xmlfile, copy=False)
             for name, xmlfile in xml_paths.items()}
# Out:
# 2014-04-07 13:03:01,052 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 13:03:02,615 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 13:03:02,617 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 13:03:13,578 -leg_joint.epithelium -INFO -Update geometry
# 2014-04-07 13:03:17,362 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 13:03:18,901 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 13:03:18,902 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 13:03:30,296 -leg_joint.epithelium -INFO -Update geometry
# 2014-04-07 13:03:34,167 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 13:03:35,711 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 13:03:35,714 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 13:03:48,064 -leg_joint.epithelium -INFO -Update geometry

# %%
eptm = epithelia['rt_1_ct2']

# %%
for path in eptm.paths.values():
    print(path, np.any([os.path.isdir(path), os.path.isfile(path)]))
# Out:
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/xml True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/svg True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/0006_2014-03-24T16_00_14.log True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14 True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/png True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/pdf True
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/params_0006_2014-03-24T16_00_14.json False
# /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/eptm_0006_2014-03-24T16_00_14.h5 False

# %%
def new_2pannels(eptm, rot=45):
    
    eptm.update_rhotheta()
    rot = -(rot + 90) * np.pi / 180
    eptm.rotate(rot)
    
    lj.local_slice(eptm, theta_amp=np.pi/12,
                   theta_c=0, zed_amp=4, zed_c=0)
    local_patch = eptm.is_local_vert.copy()
    
    lj.local_slice(eptm, theta_amp=np.pi/5, theta_c=0, zed_amp=10, zed_c=0)


    colors = eptm.rhos.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa -= 5#colors.fa.min()
    colors.fa /= 25#colors.fa.max()
    colors.a *= local_patch.a    
    eptm.graph.set_vertex_filter(None)
    
    fig, (ax_zs, ax_3d) = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
    
    ax_zs = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.proj_sigma(), ax=ax_zs,
                                 cell_kwargs={'c_text':False,
                                              'cell_colors':colors,
                                              #'c':'k',
                                              'alpha':0.4, 'normalize':False},
                                 edge_kwargs={'j_text':False,
                                              'c':'k',
                                              'lw':0.4,
                                              'alpha':0.5})
    
    
    eptm.rotate(- rot)
    
    rhos, thetas, zeds = eptm.rhos, eptm.thetas, eptm.zeds
    z_angle=np.pi/24
    d_theta = - 6 * np.pi / 7
    
    pseudo_x = eptm.graph.new_vertex_property('float')
    pseudo_y = eptm.graph.new_vertex_property('float')
    pseudo_x.a = zeds.a * np.cos(z_angle) - rhos.a * np.cos(
        thetas.a + d_theta) * np.sin(z_angle)
    pseudo_y.a = rhos.a * np.sin(thetas.a + d_theta)
    
    edge_alpha = eptm.dzeds.copy()
    
    v_depth = eptm.zeds.copy()
    v_depth.a = rhos.a * (1 - np.cos(thetas.a + d_theta))
    
    v_prop = v_depth
    
    alpha0 = 0.
    edge_alpha.a = np.array([(v_prop[s] + v_prop[t])
                             for s, t in eptm.graph.edges()])
    
    edge_alpha.a -= edge_alpha.a.min()
    edge_alpha.a += alpha0 * edge_alpha.a.max()
    
    edge_alpha.a /= edge_alpha.a.max()
    
    
    
    ax_3d = lj.plot_edges_generic(eptm, pseudo_x, pseudo_y, ax=ax_3d, efilt=None,
                                  edge_alpha=edge_alpha,
                                  edge_color=edge_alpha,
                                  j_text=False, 
                                  c='g',
                                  lw=0.6)
    
    ax_3d.plot([-40, -40], [-15, -20], '-k', lw=2)
    ax_zs.plot([-20, -20], [-15, -20], '-k', lw=2)
    
    for ax in (ax_zs, ax_3d):
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_frame_on(False)
        ax.set_ylim(-35, 35)
        
    plt.savefig(os.path.join(eptm.paths['svg'], 'two_pannels.svg'))

# %%
new_2pannels(epithelia['rt_1_ct2'])
# Out:
# /home/guillaume/python3/lib/python3.3/site-packages/matplotlib-1.4.x-py3.3-linux-x86_64.egg/matplotlib/figure.py:1617: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
new_2pannels(epithelia['rt_0_ct1'])

# %%
new_2pannels(epithelia['before'])

# %%
def new_aniso(eptm, name, rot=45):
    
    
    rot = -(rot + 90) * np.pi / 180
    eptm.rotate(rot)
    
    sigmas = eptm.proj_sigma()
    coords = [eptm.zeds, sigmas]
      
    anisotropies, orientations = eptm.cells.get_anisotropies(coords)
    lj.local_slice(eptm, theta_amp=np.pi/12,
                   theta_c=0, zed_amp=4, zed_c=0)
    local_patch = eptm.is_local_vert.copy()
    
    lj.local_slice(eptm, theta_amp=np.pi/5,
                   theta_c=0, zed_amp=10, zed_c=0)

    fig, axes = plt.subplots(1, 4, figsize=(10, 4))
    ax_depth, ax_aniso, ax_area, ax_orient = axes

    ### Depth
    
    colors = eptm.rhos.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa -= 5
    colors.fa /= 25
    colors.a *= local_patch.a    
    eptm.graph.set_vertex_filter(None)
    
    ax_depth = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.proj_sigma(),
                                     ax=ax_depth,
                                     cell_kwargs={'c_text': False,
                                                  'cell_colors': colors,
                                                  'cmap': 'afmhot_r',
                                                  'alpha': 1., 
                                                  'normalize': False},
                                     edge_kwargs={'j_text':False,
                                                  'c':'k',
                                                  'lw':0.4,
                                                  'alpha':0.5})
    
    ax_depth.set_title('{}: Depth'.format(name))
    
    
    ## Anisotropy
    colors = anisotropies.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa = colors.fa.clip(0, 7)
    colors.fa /= 7
    eptm.graph.set_vertex_filter(None)
    colors.a *= local_patch.a
    ax_aniso = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.proj_sigma(), ax=ax_aniso,
                                    cell_kwargs={'c_text':False,
                                                 'cell_colors':colors,
                                                 'cmap':'afmhot_r',
                                                 'alpha':1., 'normalize':False},
                                    edge_kwargs={'j_text':False,
                                                 'c':'k',
                                                 'lw':0.4,
                                                 'alpha':0.5})
    ax_aniso.set_title('Anisotropy')
    
    ### Areas
    colors = eptm.cells.areas.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa = colors.fa.clip(0, 17)
    colors.fa /= 17
    eptm.graph.set_vertex_filter(None)
    colors.a *= local_patch.a
    ax_area = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.proj_sigma(), ax=ax_area,
                                    cell_kwargs={'c_text':False,
                                                 'cell_colors':colors,
                                                 'cmap':'afmhot_r',
                                                 'alpha':1., 'normalize':False},
                                    edge_kwargs={'j_text':False,
                                                 'c':'k',
                                                 'lw':0.4,
                                                 'alpha':0.5})

    ax_area.set_title('Area (µm²)')
    
    ### Orientation
    colors = orientations.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa = colors.fa.clip(0, 90)
    colors.fa /= 90
    eptm.graph.set_vertex_filter(None)
    colors.a *= local_patch.a
    ax_orient = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.proj_sigma(), ax=ax_orient,
                                    cell_kwargs={'c_text':False,
                                                 'cell_colors':colors,
                                                 'cmap':'afmhot_r',
                                                 'alpha':0.8, 'normalize':False},
                                    edge_kwargs={'j_text':False,
                                                 'c':'k',
                                                 'lw':0.4,
                                                 'alpha':0.5})

    eptm.rotate(- rot)

    
    for ax in axes:
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_xlim(-10, 10)
        ax.set_ylim(-13, 13)
        ax.set_aspect('equal')
    ax_orient.set_title('Orientation (°)')
    saved_name = os.path.join('/home/guillaume/Projets/Droso/Simulations/', name+'_two_pannels.svg')
    plt.savefig(saved_name)
    print('saved to {}'.format(saved_name))

# %%
#eptm.graph.set_vertex_filter(eptm.is_local_vert)
anisotropies, orientations = eptm.cells.get_anisotropies(coords)
#eptm.graph.set_vertex_filter(None)

# %%
np.sqrt(17 / 40)
# Out:
# 0.65192024052026487

# %%
for name, xmlfile in xml_paths.items():
     eptm = lj.Epithelium(xmlfile, copy=False)
     new_aniso(eptm, name)
# Out:
# 2014-04-07 18:12:34,453 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:12:36,029 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:12:36,031 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:12:49,194 -leg_joint.epithelium -INFO -Update geometry
# 2014-04-07 18:13:05,010 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:13:06,544 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:13:06,546 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:13:17,924 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_1_ct2_two_pannels.svg
# saved to /home/guillaume/Projets/Droso/Simulations/30_regular_two_pannels.svg
# 2014-04-07 18:13:35,033 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:13:36,661 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:13:36,663 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:13:48,232 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/5_random_two_pannels.svg
# 2014-04-07 18:14:02,619 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:14:04,246 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:14:04,248 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:14:16,739 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/20_random_two_pannels.svg
# 2014-04-07 18:14:32,122 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:14:33,704 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:14:33,706 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:14:45,324 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/20_regular_two_pannels.svg
# /home/guillaume/python3/lib/python3.3/site-packages/scipy/optimize/minpack.py:418: RuntimeWarning: Number of calls to function has reached maxfev = 800.
#   warnings.warn(errors[info][0], RuntimeWarning)
# 2014-04-07 18:15:01,045 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:15:02,640 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:15:02,643 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:15:14,355 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/5_regular_two_pannels.svg
# 2014-04-07 18:15:29,351 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:15:30,917 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:15:30,919 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:15:42,002 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_05_ct2_two_pannels.svg
# 2014-04-07 18:15:57,634 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:15:59,259 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:15:59,260 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:16:10,753 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/10_regular_two_pannels.svg
# 2014-04-07 18:16:25,596 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:16:27,309 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:16:27,311 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:16:40,674 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_1_ct1_two_pannels.svg
# 2014-04-07 18:16:55,918 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:16:57,477 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:16:57,480 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:17:08,496 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_1_ct3_two_pannels.svg
# 2014-04-07 18:17:25,083 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:17:26,843 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:17:26,846 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:17:37,786 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/10_random_two_pannels.svg
# 2014-04-07 18:17:51,908 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:17:53,461 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:17:53,463 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:18:04,296 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_0_ct2_two_pannels.svg
# 2014-04-07 18:18:21,654 -leg_joint.epithelium -INFO -Instanciating epithelium 0
# 2014-04-07 18:18:23,236 -leg_joint.epithelium -INFO -Initial cells
# 2014-04-07 18:18:23,239 -leg_joint.epithelium -INFO -Initial junctions
# 2014-04-07 18:18:34,082 -leg_joint.epithelium -INFO -Update geometry
# saved to /home/guillaume/Projets/Droso/Simulations/rt_2_ct2_two_pannels.svg

# %%
new_aniso(epithelia['before'], 'before')
# Out:
# saved to /home/guillaume/Projets/Droso/Simulations/before_two_pannels.svg

# %%
new_aniso(epithelia['rt_1_ct2'])
# Out:
# saved to /home/guillaume/Python/leg-joint/saved_graphs/0006_2014-03-24T16_00_14/svg/aniso_orient_area.svg

# %%
new_aniso(epithelia['rt_0_ct1'])
# Out:
# saved to /home/guillaume/Python/leg-joint/saved_graphs/0000_2014-03-24T16_00_14/svg/aniso_orient_area.svg

# %%
eptm_a = epithelia['single_after']
eptm_b = epithelia['before']
eptm_i = epithelia['intermediate']

a_cell = eptm_i.graph.vertex(5024)
theta_a = eptm_i.thetas[a_cell]
eptm_i.rotate(-theta_a)
eptm_a.rotate(-theta_a)
eptm_b.rotate(-theta_a)

# %%
def apical_sagital(eptm, ax_a, ax_s):
    
    lj.local_slice(eptm, theta_amp=np.pi/15,
                   theta_c=0, zed_amp=10, zed_c=0)
    colors = eptm.rhos.copy()
    eptm.graph.set_vertex_filter(eptm.is_cell_vert)
    colors.fa -= 5#colors.fa.min()
    colors.fa /= 25#colors.fa.max()
    eptm.graph.set_vertex_filter(None)

    edge_color = eptm.dzeds.copy()

    edge_color.a = np.array([(colors[s] + colors[t])
                             for s, t in eptm.graph.edges()])

    ax_s = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.ixs, ax=ax_s,
                                 cell_kwargs={'c_text':False,
                                              'cell_colors':colors,
                                              #'c':'k',
                                              'alpha':0.1, 'normalize':False},
                                 edge_kwargs={'j_text':False,
                                              'edge_color':edge_color,
                                              'lw':1.,
                                              'alpha':0.5})
    ax_a = lj.plot_eptm_generic(eptm, eptm.zeds, eptm.wys, ax=ax_a,
                                 cell_kwargs={'c_text':False,
                                              'cell_colors':colors,
                                              #'c':'k',
                                              'alpha':0.5, 'normalize':False},
                                 edge_kwargs={'j_text':False,
                                              'edge_color':edge_color,
                                              'lw':1.,
                                              'alpha':0.5})

# %%
fig, axes = plt.subplots(2, 3, sharex='col', sharey='row', figsize=(12, 6))

eptms = [eptm_b, eptm_i, eptm_a]

for eptm, [ax_s, ax_a] in zip(eptms, axes.T):
    apical_sagital(eptm, ax_a, ax_s)
    
plt.savefig('../doc/imgs/single_cell.svg')
