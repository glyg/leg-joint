# %%
# %run nb_init.py

# %%
import IPython.core.display as disp

# %%
# !ls ../saved_graphs
# Out:
# 0000_2014-03-01T19_48_45  0002_2014-03-01T19_48_45  avi      old  png  xml
# 0001_2014-03-01T19_48_45  0003_2014-03-01T19_48_45  blender  pdf  svg

# %%
dir_list = os.listdir('../saved_graphs/')
dir_list = [d for d in dir_list if '2014' in d]
dir_list = [os.path.join('../saved_graphs/', d, 'png') for d in dir_list]
dir_num = 2

png_list = os.listdir(dir_list[dir_num])
png_list.sort()
print(png_list[-1])

disp.Image(os.path.join(dir_list[dir_num], png_list[-1]))
# Out:
# eptm3d_0215.png

# %%
# !ls -lht ../saved_graphs/0000_2014-03-01T19_48_45/png | head
# Out:
# total 38M
# -rw-rw-r-- 1 guillaume guillaume 303K mars   1 21:23 eptm2d_0215.png
# -rw-rw-r-- 1 guillaume guillaume 327K mars   1 21:23 eptm3d_0215.png
# -rw-rw-r-- 1 guillaume guillaume 302K mars   1 21:13 eptm2d_0059.png
# -rw-rw-r-- 1 guillaume guillaume 326K mars   1 21:13 eptm3d_0059.png
# -rw-rw-r-- 1 guillaume guillaume 302K mars   1 21:11 eptm2d_0058.png
# -rw-rw-r-- 1 guillaume guillaume 326K mars   1 21:11 eptm3d_0058.png
# -rw-rw-r-- 1 guillaume guillaume 302K mars   1 21:11 eptm2d_0057.png
# -rw-rw-r-- 1 guillaume guillaume 326K mars   1 21:11 eptm3d_0057.png
# -rw-rw-r-- 1 guillaume guillaume 302K mars   1 21:10 eptm2d_0056.png
