# %%
# %run nb_init.py

# %%
import IPython.core.display as disp

# %%
# !ls -lt ../saved_graphs/
# Out:
# total 128
# drwxrwxr-x  6 guillaume guillaume  4096 mars   4 15:16 single_2014-03-04T14_11_36
# drwxrwxr-x  6 guillaume guillaume  4096 mars   4 15:08 joint_2014-03-04T14_02_13
# drwxrwxr-x  6 guillaume guillaume  4096 mars   4 10:14 joint_2014-03-04T09_14_41
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 23:19 expl_0003_2014-03-03T22_17_48
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 22:57 expl_0001_2014-03-03T21_55_26
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 17:34 expl_0000_2014-03-03T16_31_51
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 17:34 expl_0005_2014-03-03T16_31_51
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 17:34 expl_0002_2014-03-03T16_31_51
# drwxrwxr-x  6 guillaume guillaume  4096 mars   3 17:34 expl_0004_2014-03-03T16_31_51
# drwxrwxr-x  2 guillaume guillaume 28672 mars   2 12:13 xml
# drwxrwxr-x  3 guillaume guillaume  4096 mars   1 20:22 pdf
# drwxrwxr-x 16 guillaume guillaume 36864 févr.  3 22:30 png
# drwxr-xr-x  2 guillaume guillaume  4096 janv.  7 11:40 old
# drwxrwxr-x  2 guillaume guillaume  4096 déc.   9 20:38 avi
# drwxr-xr-x  3 guillaume guillaume  4096 nov.  19 14:00 svg
# drwxrwxr-x  2 guillaume guillaume  4096 avril 13  2013 blender

# %%
dir_list = os.listdir('../saved_graphs/')
dir_list = [d for d in dir_list if 'expl' in d]
dir_list.sort()
png_dir_list = [os.path.join('../saved_graphs/', d, 'png') for d in dir_list]
svg_list = [os.path.join('../saved_graphs/', d, 'svg', 'avg_rho_%s.svg' % d) for d in dir_list]
json_list = [os.path.join('../saved_graphs/', d, 'params_%s.json' %d) for d in dir_list]
dir_num = 0

png_list = os.listdir(png_dir_list[dir_num])
png_list.sort()
print(json_list[dir_num])
latest = os.path.join(png_dir_list[dir_num], png_list[-1])

print(latest)

with open(json_list[dir_num]) as json_file:
    kwargs = json.load(json_file)
    for key, sub_kwarg in kwargs.items():
        print(key)
        for sub_key, val in sub_kwarg.items():
            print('\t %s : %.2f' % (sub_key, val))
        print('\n')

disp.Image(latest)
# Out:
# ../saved_graphs/expl_0000_2014-03-03T16_31_51/params_expl_0000_2014-03-03T16_31_51.json
# ../saved_graphs/expl_0000_2014-03-03T16_31_51/png/eptm3d_4626.png
# post_kwargs
# 	 max_ci : 4.00
# 	 span_ci : 3.00
# 	 rate_ci : 1.00
#
#
# apopto_kwargs
# 	 contractility : 1.00
# 	 radial_tension : 0.00
# 	 vol_reduction : 0.50
#
#
# seq_kwargs
# 	 ventral_bias : 1.00
# 	 seed : 1.00
# 	 p0 : 1.00
# 	 random : 1.00
# 	 width_apopto : 2.00
# 	 gamma : 1.00
# 	 num_cells : 30.00
# 	 num_steps : 10.00
# 	 amp : 0.30

# %%
for i, json_fname in enumerate(json_list):
    
    with open(json_fname) as json_file:
        kwargs = json.load(json_file)
    print('index: {} => \n'.format(i)) 
    for key, val in kwargs['post_kwargs'].items():
        print('\t {}: {}'.format(key, val))
    print('\t radial_tension : {}'.format(
          kwargs['apopto_kwargs']['radial_tension']))
    print('\n')
# Out:
# index: 0 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 1.0
# 	 radial_tension : 0.0
#
#
# index: 1 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 1.0
# 	 radial_tension : 0.2
#
#
# index: 2 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 2
# 	 radial_tension : 0.0
#
#
# index: 3 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 1.0
# 	 radial_tension : 0.2
#
#
# index: 4 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 2
# 	 radial_tension : 0.0
#
#
# index: 5 =>
#
# 	 max_ci: 4.0
# 	 span_ci: 3.0
# 	 rate_ci: 2
# 	 radial_tension : 0.2

# %%
disp.SVG(svg_list[dir_num])

# %%
latest_2d = os.path.join(png_dir_list[dir_num], png_list[len(png_list)//2-1])
disp.Image(latest_2d)

# %%
latest_2d
# Out:
# '../saved_graphs/expl_0003_2014-03-03T22_17_48/png/eptm2d_4625.png'

# %%
# !ls -lht ../saved_graphs/expl_0001_2014-03-03T07_56_29/svg
# Out:
# total 28K
# -rw-rw-r-- 1 guillaume guillaume 28K mars   3 12:17 avg_rho_expl_0001_2014-03-03T07_56_29.svg

# %%
# Out:
# {'apopto_kwargs': {'contractility': 1.2,
#   'radial_tension': 0.0,
#   'vol_reduction': 0.7},
#  'post_kwargs': {'max_ci': 3.0, 'rate_ci': 1.0, 'span_ci': 2},
#  'seq_kwargs': {'amp': 0.3,
#   'gamma': 1.0,
#   'num_cells': 30,
#   'num_steps': 10,
#   'p0': 1.0,
#   'random': True,
#   'seed': 1,
#   'ventral_bias': True,
#   'width_apopto': 2.0}}
