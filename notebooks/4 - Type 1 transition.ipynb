# %% [markdown]
# # Type one transition
#
# Please refer the original definition in  [Farhadifar et al. Curr Biol. 2007](http://dx.doi.org/10.1016/j.cub.2007.11.049),
# Suppplementary figure S1)
#
# In `ASCII art` (letters represent junctions and number represent cells):
#
#     e 2 d
#      \ /         e  d        e  2  d
#       b           \/          \   /
#     1 | 3  ---->  ab  ----> 1  a-b  3
#       a           /\          /   \
#      / \         f  c        f  4  c
#     f 4 c
#
# ### Paramters
#
# The arguments can be either:
#
# * two cell vertices (**1** and **3**),
# * two junction vertices (**a** and **b**)
# * or a single edge (between **a** and **b**)

# %%
# %run nb_init.py
eptm = lj.Epithelium(#graphXMLfile='../saved_graphs/few_big_cells.xml',
                     paramfile='../default/few_big_cells.xml')
# Out:
# Initial cells
# Initial junctions
# 2 triangles were dropped
# 2 junction edges were dropped
# Scaling all the distances by a factor 0.759

# %%
# I keep this as a run command to avoid kernel restarts
# %run ../src/graph_representation.py
# plot_cells_sz(eptm, vfilt=None)

# %%
eptm.set_local_mask(None)
cell1, cell3 = eptm.graph.vertex(17), eptm.graph.vertex(18)
eptm.set_local_mask(cell1)
eptm.set_local_mask(cell3)

# %%
@before_after
def show_type1(eptm, cells):
    cell1, cell3 = cells
    modified_cells, modified_jverts = lj.type1_transition(eptm, (cell1, cell3))
    
show_type1(eptm, (cell1, cell3))

# %% [markdown]
# ### Energy minimisation

# %%
local_optimum(eptm, tol=1e-4)
# Out:
# (array([ 13.9945916 ,   3.23191249,  17.38499096,   3.82339353,
#         16.79350992,  -1.61595625,  13.9945916 ,   6.46382498,
#         16.79350992,   8.07978123,  19.59242824,  -3.23191249,
#         19.00094721,   1.02447521,  22.39134656,   1.61595625,
#         22.39134656,  -1.61595625,  19.59242824,   6.46382498]),
#  (array([ 14.15246363,   3.6238337 ,  17.98587215,   2.97786753,
#         16.8681136 ,  -1.57448344,  13.48346356,   7.49982358,
#         16.66060416,   8.99162912,  19.64987591,  -3.51817282,
#         18.28006945,   2.4524676 ,  22.36287216,   1.60352616,
#         22.63175467,  -1.80779626,  19.64038253,   7.26439503]),
#   0.49444820443762216,
#   {'funcalls': 11,
#    'grad': array([  1.11188836e-05,   2.18325358e-05,  -2.10720330e-05,
#          4.66848782e-06,   1.63535852e-05,   1.44884105e-06,
#          1.29340982e-05,  -4.92939023e-06,   1.86295424e-05,
#         -2.49800181e-07,  -5.32907052e-06,   5.05706588e-06,
#          1.74082970e-05,   1.78301818e-05,  -1.42663659e-06,
#         -3.26683125e-05,  -1.88737914e-06,   8.42659276e-06,
#         -1.06470388e-05,   3.14193116e-06]),
#    'task': 'CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL',
#    'warnflag': 0}))

# %%
eptm.graph.save('../saved_graphs/nb_division.xml.gz')
