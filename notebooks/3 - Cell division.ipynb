# %%
# %run nb_init.py
eptm = lj.Epithelium(#graphXMLfile='../saved_graphs/nb_division.xml.gz',
                     paramfile='../default/few_big_cells.xml')
# Out:
# Initial cells
# Initial junctions
# 2 triangles were dropped
# 2 junction edges were dropped
# Scaling all the distances by a factor 0.759

# %% [markdown]
# ## Abscission of a cell

# %%
@before_after
def show_division(eptm, mother_cell):
    eptm.cells.prefered_area[mother_cell] /= 2.
    eptm.cells.contractilities[mother_cell] /= 2.
    for edge in eptm.cell_junctions(mother_cell):
        eptm.junctions.line_tensions[edge] /= (2*(1.5))
    j= lj.cell_division(eptm, mother_cell, verbose=True)

#jv0, jv1, mother_cell, daughter_cell = j
eptm.set_local_mask(None)
mother_cell = eptm.graph.vertex(17)
eptm.set_local_mask(mother_cell)

show_division(eptm, mother_cell)
#print j
# Out:
# Cell 117 is born

# %% [markdown]
# ## Energy minimisation

# %%
pos0, pos1 = local_optimum(eptm, tol=1e-4)
# Out:
# (array([ 16.79350992,   1.61595625,  16.79350992,  -1.61595625,
#         19.59242824,  -3.23191249,  19.59242824,   3.23191249,
#         22.39134656,   1.61595625,  22.39134656,  -1.61595625,
#         16.79350992,  -0.89868421,  22.39134656,   0.89868421]),
#  (array([  1.71518256e+01,   1.59319627e+00,   1.74589261e+01,
#         -1.65908436e+00,   1.95918680e+01,  -3.12973823e+00,
#          1.95959471e+01,   3.93083917e+00,   2.20707273e+01,
#          1.59316150e+00,   2.17079314e+01,  -1.66590522e+00,
#          1.80055305e+01,  -1.13157167e-02,   2.11803002e+01,
#         -5.27139102e-03]),
#   0.41260595388072369,
#   {'funcalls': 9,
#    'grad': array([  2.91711100e-05,   7.61168906e-05,  -1.88682403e-05,
#         -6.65578703e-06,   4.27435864e-06,  -4.27380353e-05,
#         -1.38222767e-06,  -6.26332319e-05,   8.25839397e-05,
#          2.12718732e-05,  -4.95548047e-05,  -4.05175893e-05,
#         -6.30051566e-06,  -9.49684775e-05,  -1.58761893e-05,
#         -2.62900812e-05]),
#    'task': 'CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL',
#    'warnflag': 0}))

# %%
eptm.graph.save('../saved_graphs/nb_division.xml.gz')
